# %% [markdown]
# ## Object detection with Yolo v5

# %% [markdown]
# #### Import pytorch library as well as its dependencies from official site of pytorch
# - pip install https://download.pytorch.org/whl/cpu/torch-0.4.1-cp37-cp37m-win_amd64.whl
# - conda install pytorch torchvision -c pytorch
# - Dependencies :
# - pip install -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt

# %%
#Import necessary libraries
# !pip uninstall torchvision
# conda install pytorch torchvision -c pytorch
# !pip install -r
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'pytorch'

# %%
import cv2
import torch
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the pretrained Yolov5 model by specifying pretrained parameter as True
yolo_model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained = True)
# Out:
# Using cache found in /Users/padamakshagund/.cache/torch/hub/ultralytics_yolov5_master
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Load the pretrained Yolov5 model by specifying pretrained parameter as True
# ----> 2 yolo_model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained = True)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/hub.py:404, in load(repo_or_dir, model, source, force_reload, verbose, skip_validation, *args, **kwargs)
#     401 if source == 'github':
#     402     repo_or_dir = _get_cache_or_reload(repo_or_dir, force_reload, verbose, skip_validation)
# --> 404 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     405 return model
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/hub.py:433, in _load_local(hubconf_dir, model, *args, **kwargs)
#     430 hub_module = _import_module(MODULE_HUBCONF, hubconf_path)
#     432 entry = _load_entry_from_hubconf(hub_module, model)
# --> 433 model = entry(*args, **kwargs)
#     435 sys.path.remove(hubconf_dir)
#     437 return model
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py:93, in yolov5s(pretrained, channels, classes, autoshape, _verbose, device)
#      91 def yolov5s(pretrained=True, channels=3, classes=80, autoshape=True, _verbose=True, device=None):
#      92     # YOLOv5-small model https://github.com/ultralytics/yolov5
# ---> 93     return _create('yolov5s', pretrained, channels, classes, autoshape, _verbose, device)
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py:33, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      17 """Creates or loads a YOLOv5 model
#      18
#      19 Arguments:
#    (...)
#      29     YOLOv5 model
#      30 """
#      31 from pathlib import Path
# ---> 33 from models.common import AutoShape, DetectMultiBackend
#      34 from models.experimental import attempt_load
#      35 from models.yolo import ClassificationModel, DetectionModel, SegmentationModel
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:28
#      25 from torch.cuda import amp
#      27 from utils import TryExcept
# ---> 28 from utils.dataloaders import exif_transpose, letterbox
#      29 from utils.general import (LOGGER, ROOT, Profile, check_requirements, check_suffix, check_version, colorstr,
#      30                            increment_path, is_jupyter, make_divisible, non_max_suppression, scale_boxes, xywh2xyxy,
#      31                            xyxy2xywh, yaml_load)
#      32 from utils.plots import Annotator, colors, save_one_box
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/utils/dataloaders.py:25
#      23 import torch
#      24 import torch.nn.functional as F
# ---> 25 import torchvision
#      26 import yaml
#      27 from PIL import ExifTags, Image, ImageOps
#
# File ~/anaconda3/lib/python3.10/site-packages/torchvision/__init__.py:7
#       5 from torchvision import datasets
#       6 from torchvision import io
# ----> 7 from torchvision import models
#       8 from torchvision import ops
#       9 from torchvision import transforms
#
# File ~/anaconda3/lib/python3.10/site-packages/torchvision/models/__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# File ~/anaconda3/lib/python3.10/site-packages/torchvision/models/convnext.py:8
#       5 from torch import nn, Tensor
#       6 from torch.nn import functional as F
# ----> 8 from ..ops.misc import Conv2dNormActivation, Permute
#       9 from ..ops.stochastic_depth import StochasticDepth
#      10 from ..transforms._presets import ImageClassification
#
# File ~/anaconda3/lib/python3.10/site-packages/torchvision/ops/__init__.py:18
#      16 from .deform_conv import deform_conv2d, DeformConv2d
#      17 from .diou_loss import distance_box_iou_loss
# ---> 18 from .drop_block import drop_block2d, DropBlock2d, drop_block3d, DropBlock3d
#      19 from .feature_pyramid_network import FeaturePyramidNetwork
#      20 from .focal_loss import sigmoid_focal_loss
#
# File ~/anaconda3/lib/python3.10/site-packages/torchvision/ops/drop_block.py:2
#       1 import torch
# ----> 2 import torch.fx
#       3 import torch.nn.functional as F
#       4 from torch import nn, Tensor
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/fx/__init__.py:83
#       1 r'''
#       2 FX is a toolkit for developers to use to transform ``nn.Module``
#       3 instances. FX consists of three main components: a **symbolic tracer,**
#    (...)
#      80 repository.
#      81 '''
# ---> 83 from .graph_module import GraphModule
#      84 from ._symbolic_trace import symbolic_trace, Tracer, wrap, PH, ProxyableClassMeta
#      85 from .graph import Graph, CodeGen
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/fx/graph_module.py:8
#       6 import linecache
#       7 from typing import Type, Dict, List, Any, Union, Optional, Set
# ----> 8 from .graph import Graph, _PyTreeCodeGen, _is_from_torch, _custom_builtins, PythonCode
#       9 from ._compatibility import compatibility
#      10 from torch.package import Importer, sys_importer
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/fx/graph.py:1
# ----> 1 from .node import Node, Argument, Target, map_arg, _type_repr, _get_qualified_name
#       2 import torch.utils._pytree as pytree
#       3 from . import _pytree as fx_pytree
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/fx/node.py:34
#      20 Target = Union[Callable[..., Any], str]
#      22 Argument = Optional[Union[
#      23     Tuple[Any, ...],  # actually Argument, but mypy can't represent recursive types
#      24     List[Any],  # actually Argument
#    (...)
#      28     BaseArgumentTypes
#      29 ]]
#      31 _side_effectful_functions: Set[Callable] = {
#      32     torch._assert,
#      33     torch.ops.profiler._record_function_enter,
# ---> 34     torch.ops.profiler._record_function_enter_new,
#      35     torch.ops.profiler._record_function_exit}
#      37 # this is fixed on master, WAR for 1.5
#      38 def _find_module_of_method(orig_method: Callable[..., Any]) -> str:
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/_ops.py:167, in __getattr__(self, op_name)
#     165 def __call__(self, *args, **kwargs):
#     166     flat_args = _to_flat_tuple(args, kwargs)
# --> 167     if torch.overrides.has_torch_function(flat_args):
#     168         return torch.overrides.handle_torch_function(
#     169             self, flat_args, *args, **kwargs
#     170         )
#     172     dispatch_key_set = _compute_keyset(args, kwargs)
#
# RuntimeError: No such operator profiler::_record_function_enter_new

# %%
import os 
os.getcwd()
# Out:
# '/Users/padamakshagund/Desktop/Data Science/DEEP Learning/Object_detection'

# %%
# Download the images from https://pixabay.com/images/search/people/

# Read the images using PIL and opencv libraries

image1 = Image.open('Planes11.jpg')  # PIL image
image2 = cv2.imread('airplane_277.jpg')[..., ::-1]  # OpenCV image (BGR to RGB)

# %%
# VISUALIZATION
import matplotlib.pyplot as plt # MATPLOTLIB FOR PLOTTING
import seaborn as sns
# %matplotlib inline
plt.imshow(image1)
plt.show()

# %%
plt.imshow(image2)

# %%
# create batch/list of images

image_list = [image1, image2]

# %%
# Inferences obtained by passing above images to pretrained model object.

inferences = yolo_model(image_list, size = 640)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[33], line 3
#       1 # Inferences obtained by passing above images to pretrained model object.
# ----> 3 inferences = yolo_model(image_list, size = 640)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:708, in AutoShape.forward(self, ims, size, augment, profile)
#     706 # Post-process
#     707 with dt[2]:
# --> 708     y = non_max_suppression(y if self.dmb else y[0],
#     709                             self.conf,
#     710                             self.iou,
#     711                             self.classes,
#     712                             self.agnostic,
#     713                             self.multi_label,
#     714                             max_det=self.max_det)  # NMS
#     715     for i in range(n):
#     716         scale_boxes(shape1, y[i][:, :4], shape0[i])
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/utils/general.py:982, in non_max_suppression(prediction, conf_thres, iou_thres, classes, agnostic, multi_label, labels, max_det, nm)
#     980 c = x[:, 5:6] * (0 if agnostic else max_wh)  # classes
#     981 boxes, scores = x[:, :4] + c, x[:, 4]  # boxes (offset by class), scores
# --> 982 i = torchvision.ops.nms(boxes, scores, iou_thres)  # NMS
#     983 i = i[:max_det]  # limit detections
#     984 if merge and (1 < n < 3E3):  # Merge NMS (boxes merged using weighted mean)
#     985     # update boxes as boxes(i,4) = weights(i,n) * boxes(n,4)
#
# File ~/anaconda3/lib/python3.10/site-packages/torchvision/ops/boxes.py:40, in nms(boxes, scores, iou_threshold)
#      38 if not torch.jit.is_scripting() and not torch.jit.is_tracing():
#      39     _log_api_usage_once(nms)
# ---> 40 _assert_has_ops()
#      41 return torch.ops.torchvision.nms(boxes, scores, iou_threshold)
#
# File ~/anaconda3/lib/python3.10/site-packages/torchvision/extension.py:33, in _assert_has_ops()
#      31 def _assert_has_ops():
#      32     if not _has_ops():
# ---> 33         raise RuntimeError(
#      34             "Couldn't load custom C++ ops. This can happen if your PyTorch and "
#      35             "torchvision versions are incompatible, or if you had errors while compiling "
#      36             "torchvision from source. For further information on the compatible versions, check "
#      37             "https://github.com/pytorch/vision#installation for the compatibility matrix. "
#      38             "Please check your PyTorch version with torch.__version__ and your torchvision "
#      39             "version with torchvision.__version__ and verify if they are compatible, and if not "
#      40             "please reinstall torchvision so that it matches your PyTorch install."
#      41         )
#
# RuntimeError: Couldn't load custom C++ ops. This can happen if your PyTorch and torchvision versions are incompatible, or if you had errors while compiling torchvision from source. For further information on the compatible versions, check https://github.com/pytorch/vision#installation for the compatibility matrix. Please check your PyTorch version with torch.__version__ and your torchvision version with torchvision.__version__ and verify if they are compatible, and if not please reinstall torchvision so that it matches your PyTorch install.

# %%
inferences
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 inferences
#
# NameError: name 'inferences' is not defined

# %%
# Print the inference using function
inferences.print()
# Out:
# image 1/2: 340x511 2 persons
# image 2/2: 340x510 7 persons, 1 tie, 2 laptops
# Speed: 8.1ms pre-process, 237.7ms inference, 5.0ms NMS per image at shape (2, 3, 448, 640)

# %%
inferences.show()

# %%
# save the detection images on disk
inferences.save()
# Out:
# Saved 2 images to runs/detect/exp3

# %%
# we can show image predictions using tensor
inferences.xyxy[0]
# Out:
# tensor([[232.11284,  42.66807, 367.95233, 324.63095,   0.94145,   0.00000],
#         [122.97870,  64.52874, 252.51003, 322.44742,   0.90267,   0.00000]])

# %%
# Also, we can represent the result with pandas dataframe
inferences.pandas().xyxy[0]
# Out:
#          xmin       ymin        xmax        ymax  confidence  class    name
# 0  232.112839  42.668068  367.952332  324.630951    0.941454      0  person
# 1  122.978699  64.528740  252.510025  322.447418    0.902672      0  person

# %% [markdown]
# ## Happy Learning :)
